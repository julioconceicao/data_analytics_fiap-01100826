# %%
# Entendimento dos Dados

## Objetivo

Este notebook tem como objetivo conhecer a estrutura do dataset da Olist, identificando as tabelas utilizadas no projeto, suas chaves primárias, relacionamentos, granularidade e principais características.

# %%
## Modelo de Dados

O dataset da Olist é composto por tabelas transacionais e dimensionais.

A tabela **Orders** representa o núcleo do modelo e se relaciona com clientes, itens do pedido, pagamentos e avaliações.

O diagrama abaixo apresenta a estrutura relacional do dataset da Olist e as chaves utilizadas nas análises

![Modelo de Dados da Olist](../docs/imagens/modelo_dados_olist.png)

# %%
# import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # import pandas as pd
# ----> 2 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'
